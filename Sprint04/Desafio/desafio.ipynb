# %% [markdown]
# Subindo o CSV para o bucket:

# %%
import boto3

arquivo = r"C:\Users\twvin\OneDrive\Área de Trabalho\Compass.UOL\Sprint04\Desafio\canais-de-programacao-de-programadoras-ativos-credenciados.csv"
bucket = "desafio-sprint4-vinicius"

s3 = boto3.client(
    "s3",
    aws_access_key_id="ASIA4ETEZ2ENXV4V6W7N",
    aws_secret_access_key="8kr26X8zWX1Ylr51xev+LxJWQ6JsVH82++AjPjg+",
    aws_session_token="..."
)
s3.upload_file(arquivo, bucket, "canais-de-programacao-de-programadoras-ativos-credenciados.csv")
print("Arquivo para o bucket: ", bucket) #testar se rodou
# Out:
# Arquivo para o bucket:  desafio-sprint4-vinicius
